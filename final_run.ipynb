# %%
import src.main as main
import src.visualization as viz
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/4_/c0fz5pvx5gj05ys0n4mzc4240000gn/T/ipykernel_24889/3327104321.py in <module>
# ----> 1 import src.main as main
#       2 import src.visualization as viz
#       3 import numpy as np
#
# ~/Documents/DATA 440 A&W/penney_game_final/src/main.py in <module>
#       7 import json
#       8 import matplotlib.pyplot as plt
# ----> 9 import mpld3
#      10
#      11 def shuffle_deck(seed:None):
#
# ModuleNotFoundError: No module named 'mpld3'

# %%
results = main.play_n_games(5, 'data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4_/c0fz5pvx5gj05ys0n4mzc4240000gn/T/ipykernel_24889/2518437989.py in <module>
# ----> 1 results = main.play_n_games(5, 'data')
#
# NameError: name 'main' is not defined

# %%
main.create_cards_heatmap()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4_/c0fz5pvx5gj05ys0n4mzc4240000gn/T/ipykernel_24763/1334063428.py in <module>
# ----> 1 main.create_cards_heatmap()
#
# ~/Documents/DATA 440 A&W/penney_game_final/src/main.py in create_cards_heatmap(ax)
#      72         os.makedirs('figures')
#      73     fig1.savefig('figures/cards_heatmap.png', bbox_inches='tight')
# ---> 74     mpld3.save_html(fig1, 'figures/cards_heatmap.html')
#      75     return fig1, ax1
#      76
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/tools.py in mpl_to_plotly(fig, resize, strip_style, verbose)
#     109     if matplotlylib:
#     110         renderer = matplotlylib.PlotlyRenderer()
# --> 111         matplotlylib.Exporter(renderer).run(fig)
#     112         if resize:
#     113             renderer.resize()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/matplotlylib/mplexporter/exporter.py in run(self, fig)
#      51
#      52             plt.close(fig)
# ---> 53         self.crawl_fig(fig)
#      54
#      55     @staticmethod
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_fig(self, fig)
#     122         with self.renderer.draw_figure(fig=fig, props=utils.get_figure_properties(fig)):
#     123             for ax in fig.axes:
# --> 124                 self.crawl_ax(ax)
#     125
#     126     def crawl_ax(self, ax):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_ax(self, ax)
#     144                 self.draw_patch(ax, patch)
#     145             for collection in ax.collections:
# --> 146                 self.draw_collection(ax, collection)
#     147             for image in ax.images:
#     148                 self.draw_image(ax, image)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/matplotlylib/mplexporter/exporter.py in draw_collection(self, ax, collection, force_pathtrans, force_offsettrans)
#     287
#     288         offset_dict = {"data": "before", "screen": "after"}
# --> 289         offset_order = offset_dict[collection.get_offset_position()]
#     290
#     291         self.renderer.draw_path_collection(
#
# AttributeError: 'QuadMesh' object has no attribute 'get_offset_position'

# %%
main.create_tricks_heatmap()
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <AxesSubplot: title={'center': 'My Chance of Winning (By Tricks)\n(n=95)'}, xlabel='Me'>)

# %%
main.make_heatmap_package()
# Out:
# (<Figure size 1600x800 with 3 Axes>,
#  array([<AxesSubplot: title={'center': 'My Chance of Winning (By Cards)\n(n=95)'}, xlabel='Me', ylabel='Opponent'>,
#         <AxesSubplot: title={'center': 'My Chance of Winning (By Tricks)\n(n=95)'}, xlabel='Me'>],
#        dtype=object))
